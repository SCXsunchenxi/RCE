# %%
import pandas as pd
import seaborn as sns
import random
import pickle

# %%
path_string = '../results/960tests_score.seqs'
with open(path_string,'rb') as f:
    data = pickle.load(f)

# %%
df = pd.DataFrame(data=data)

# %%
sns.pairplot(df,hue='class')
# Out:
# /Users/sunchenxi/opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /Users/sunchenxi/opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.pairplot(df,hue='early')

# %%
path_string = '../results/960tests_score_noranking.seqs'
with open(path_string,'rb') as f:
    data = pickle.load(f)
df = pd.DataFrame(data=data)

# %%
sns.pairplot(df,hue='class')

# %%
sns.pairplot(df,hue='early')
